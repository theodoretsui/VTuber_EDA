# %% [markdown]
# # SDPA Coursework Part3
# ## A Glance at Virtual Streamer
# *Analyse the data of the top 500 VTubers in the world*

# %% [markdown]
# ### Introduction
# In this part, we will analyse the data of the top 500 VTubers in the world. In case you do not know what a VTuber is, I will explain it initially.
#
# The VTuber, or virtual Youtuber, is actually a type of content creator or live streamer. Like normal Youtuber and streamers, the VTubers attract audiences and earn earn by making videos and live broadcasts. Unlike normal Youtuber and streamers, the VTubers perform and create content by using their own virtual avatars. The development of the VTubers benefits from the real-time facial capture and motion capture technology. Generally , the VTubers have their own fictional backgrounds which are usually fancy and imaginative. Because the unique and perfect appearances of the VTubers are very attractive, the market of the VTubers is growing rapidly.
#
# In the following session, I will crawl the VTubers basic data from https://vtubie.com/ via web scraping, then, clean the data in order to make it ready for analysis, and finally, perform EDA and ask some questions from the data.
#
# > The first mainstream VTuber -- KizunaAi
# ![KizunaAi](KizunaAi.jpg)
# Picture: Kizuna Ai https://twitter.com/aichan_nel

# %% [markdown]
# ### Crawl a real-world dataset
# The website we are going to scrap is https://vtubie.com/, which is a aggregative VTubers database and community. The VTubers that I will scrap are the top 500 VTubers by number of subscriptions.
# As we can see in this page, https://vtubie.com/allvtubers/, there are 10 VTubers in the first page. Then, the url of the second page is: https://vtubie.com/allvtubers/?pg=2. Thus, in order to get the top 500 VTubers' information, we can run the following code block. The block will have a link_set that contains the urls of the VTuber information page, and it will be found by BeautifulSoup.

# %%
import requests
from bs4 import BeautifulSoup

url = "https://vtubie.com/allvtubers/?pg="
# pg_1 = requests.get("https://vtubie.com/allvtubers/?pg=1")

link_set = set() # for every vtuber's info page

for page in range(1,51): # from page=1 to page=50
    print("processing page " + str(page))
    url_full = url + str(page)
    pg_get = requests.get(url_full) # requests for one page
    pg_soup = BeautifulSoup(pg_get.text) 
    # the url contains in <a href="https://vtubie.com/kizuna-ai/" title="Visit VTuber">
    for a in pg_soup.find_all(title = "Visit VTuber"): 
        link_set.add(a.attrs['href'])
        
print(len(link_set)) # -> 500
link_set
# Out:
# processing page 1
# processing page 2
# processing page 3
# processing page 4
# processing page 5
# processing page 6
# processing page 7
# processing page 8
# processing page 9
# processing page 10
# processing page 11
# processing page 12
# processing page 13
# processing page 14
# processing page 15
# processing page 16
# processing page 17
# processing page 18
# processing page 19
# processing page 20
# processing page 21
# processing page 22
# processing page 23
# processing page 24
# processing page 25
# processing page 26
# processing page 27
# processing page 28
# processing page 29
# processing page 30
# processing page 31
# processing page 32
# processing page 33
# processing page 34
# processing page 35
# processing page 36
# processing page 37
# processing page 38
# processing page 39
# processing page 40
# processing page 41
# processing page 42
# processing page 43
# processing page 44
# processing page 45
# processing page 46
# processing page 47
# processing page 48
# ...

# %% [markdown]
# Then, we will request all the url in the link set and parse the page by BeautifulSoup to get the required information. The variable that I interest are: name, type, group, genre, gender, language, model, debut date, status, release frequency, the number of subscription, and the number of views.

# %%
import json
import numpy as np
import pandas as pd
import re

# %%
# create dataframe's header
vt_all_info_df = pd.DataFrame(columns=col_name)

# parse html -> dataframe
for idx, vtuber_info_url in enumerate(link_set):
    print(idx, end = " -> ")
    vt_info_get = requests.get(vtuber_info_url) # requests the vtuber information page
    vt_info_soup = BeautifulSoup(vt_info_get.text) # parse the html by beautifulsoup 
    
    # <h1 class="ma-nov-page-title">Kizuna Ai</h1>
    name = vt_info_soup.find("h1").get_text() # name of the vtb
    try:
#         <a href="/type/vtuber">VTuber</a>
        type_ = vt_info_soup.find_all("a", href = re.compile("/type/*"))[0].get_text()
    except IndexError:
        pass
    
    # <a href="https://vtubie.com/g/kizuna-ai-inc/">Kizuna AI Inc.</a>
    group = vt_info_soup.find_all("a", href = re.compile("https://vtubie.com/g/*"), title = False)[0].get_text()
    
    # <a href="/genre/gaming">Gaming</a>
    # A VTuber may have multiple genres. Thus, find all the genres by using regex <a href="/genre/*">*</a>
    # and store them in a list. 
    genre = vt_info_soup.find_all("a", href = re.compile("/genre/*"))
    genre_list = [(lambda s: s.get_text())(i) for i in genre]
    try:
        gender = vt_info_soup.find_all("a", href = re.compile("/gender/*"))[0].get_text()
    except IndexError:
        pass
    
    # <a href="/language/chinese">Chinese</a>
    # The same as genre. Use regex and list
    language = vt_info_soup.find_all("a", href = re.compile("/language/*"))
    language_list = [(lambda s: s.get_text())(i) for i in language]
    # <a href="/model/3d">3D</a>
    # The same as genre. Use regex and list
    model = vt_info_soup.find_all("a", href = re.compile("/model/*"))
    model_list = [(lambda s: s.get_text())(i) for i in model]
    
    # The following variables are not stored in a tag. We need to find the key string initially.
    debut = vt_info_soup.find_all(string = "Debut ")[0].parent.find_next_sibling().get_text().strip()
    status = vt_info_soup.find_all(string = "Status")[0].parent.parent.find_next_sibling().get_text().strip()
    freq = vt_info_soup.find_all(string = "Release Frequency")[0].parent.find_next_sibling().get_text().strip()
    subs = vt_info_soup.find(string = "Subs").parent.find_next_sibling().get_text().strip()
    views = vt_info_soup.find(string = "Views").parent.find_next_sibling().get_text().strip()
    
    # input all the information in DataFrame
    col = [name, type_, group, genre_list, gender, language_list, model_list, debut, status, freq, subs, views]
    col_name = ['name', 'type_', 'group', 'genre_list', 'gender', 'language_list', 'model_list', 'debut', 'status', 'freq', 'subs', 'views']
    vt_info_df = pd.DataFrame([col], columns=col_name)
    vt_all_info_df = vt_all_info_df.append(vt_info_df, ignore_index = True)

vt_all_info_df

# %% [markdown]
# Finally, the data will be stored in csv file. The data can be easily read by read_csv.

# %%
# save the dataframe into a csv
vt_all_info_df.to_csv("vt_all_info_df_origin.csv")

# %%
# read from the csv
vt_all_info_df = pd.read_csv("vt_all_info_df_origin.csv")

# %% [markdown]
# ### Data Preview
# Before cleaning the data, let us preview its structure and characteristics.

# %%
vt_all_info_df.head(10)
# Out:
#    Unnamed: 0                 name      type_        group  genre_list  \
# 0           0         Lize Helesta     VTuber    Nijisanji          []
# 1           1               Naraka     VTuber    Nijisanji          []
# 2           2         Takao Shinji     VTuber  Independent          []
# 3           3     Shellin Burgundy     VTuber    Nijisanji          []
# 4           4         Souya Ichika     VTuber      AniMare          []
# 5           5  Shimamura Charlotte     VTuber   HoneyStrap          []
# 6           6                  Cry  VStreamer  Independent     ['Art']
# 7           7        Lumi Celestia     VTuber    MAHAPANCA          []
# 8           8             Wolfychu  VStreamer  Independent  ['Gaming']
# 9           9       Sakura Ritsuki     VTuber    Nijisanji          []
#
#    gender   language_list     model_list       debut  status  \
# 0  Female    ['Japanese']  ['3D', 'L2D']  2019/03/23   + Add
# 1  Female    ['Japanese']        ['L2D']  2019/12/29   + Add
# ...

# %% [markdown]
# The first column, Unnamed: 0, is index column ,and it is meaningless.

# %%
vt_all_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     500 non-null    int64
#  1   name           500 non-null    object
#  2   type_          500 non-null    object
#  3   group          500 non-null    object
#  4   genre_list     500 non-null    object
#  5   gender         500 non-null    object
#  6   language_list  500 non-null    object
#  7   model_list     500 non-null    object
#  8   debut          500 non-null    object
#  9   status         500 non-null    object
#  10  freq           500 non-null    object
#  11  subs           500 non-null    object
#  12  views          500 non-null    object
# dtypes: int64(1), object(12)
# memory usage: 50.9+ KB

# %% [markdown]
# It seems that there is no null value.
# However, that is because the website scrap programme did not translate the meaningless elements into null value.
# In the DataFrame, the empty lists, "+ Add", and other meaningless string like " - " represent null value.
# In order to know the null value situation, we need to go through all the column using Series.value_counts()

# %%
# check how many categories in "type_"
vt_all_info_df.type_.value_counts()
# Out:
# VTuber       457
# VStreamer     43
# Name: type_, dtype: int64

# %% [markdown]
# The type_ coloum have 2 types: VTuber and VStreamer. In my opinion, the two categories are actually vague on the website. For example, Nyatasha Nyanners is a famous virtual streamer on Twitch (a live stream platform), but her type on the website is VTuber.

# %%
# check how many categories in "group"
print(vt_all_info_df.group.value_counts().head())
print("Total numbers of categories: ", vt_all_info_df.group.value_counts().count())
# Out:
# Independent    247
# Nijisanji      108
# Hololive        57
# .LIVE           12
# VShojo           9
# Name: group, dtype: int64
# Total numbers of categories:  34

# %%
# how many categories in "language"
print(vt_all_info_df.language_list.value_counts())
print("Total numbers of categories: ", vt_all_info_df.language_list.value_counts().count())
# Out:
# ['Japanese']                                    361
# ['English']                                      77
# ['Indonesian']                                   12
# ['English', 'Indonesian', 'Japanese']             5
# ['English', 'Indonesian']                         5
# ['English', 'Japanese']                           5
# ['Russian']                                       3
# ['Korean']                                        3
# ['Thai']                                          3
# ['English', 'Spanish']                            3
# ['Japanese', 'Korean']                            2
# ['English', 'Filipino', 'Japanese']               2
# ['English', 'Filipino']                           2
# ['Chinese', 'Japanese']                           2
# ['English', 'French', 'Russian']                  1
# []                                                1
# ['Japanese', 'Spanish']                           1
# ['Japanese', 'Thai']                              1
# ...

# %% [markdown]
# There is one null value in language column.

# %%
# how many categories in "genre"
print(vt_all_info_df.genre_list.value_counts().head())
print("Total numbers of categories: ", vt_all_info_df.genre_list.value_counts().count())
# Out:
# []                                 363
# ['Chatting', 'Gaming', 'Music']     32
# ['Chatting', 'Gaming']              20
# ['Gaming']                          19
# ['Music']                            5
# Name: genre_list, dtype: int64
# Total numbers of categories:  51

# %% [markdown]
# The genre_list column have many null values, and it need to be convert from list to NoneType.

# %%
# how many categories in "gender"
print(vt_all_info_df.gender.value_counts())
print("Total numbers of categories: ", vt_all_info_df.gender.value_counts().count())
# Out:
# Female         411
# Male            81
# Agender          5
# Genderfluid      2
# Non-binary       1
# Name: gender, dtype: int64
# Total numbers of categories:  5

# %% [markdown]
# The gender column have 5 categories. To simplified, turn all the non-binary categories in to "non-binary".

# %%
# how many categories in "model_list"
vt_all_info_df.model_list.value_counts()
# Out:
# ['L2D']                         177
# []                              127
# ['3D', 'L2D']                   109
# ['3D']                           80
# ['3D', 'JPEG', 'L2D']             1
# ['JPEG', 'L2D']                   1
# ['Model', 'L2D']                  1
# ['JPEG', 'L2D', 'PNG']            1
# ['L2D', 'PNG']                    1
# ['PNG']                           1
# ['3D', 'GIF', 'JPEG', 'PNG']      1
# Name: model_list, dtype: int64

# %% [markdown]
# The modol_list has 4 kinds of model, picture type, GIF, 3D and L2D (Live2D).

# %%
# how many categories in "status"
vt_all_info_df.status.value_counts()
# Out:
# + Add      333
# Active     158
# Retired      9
# Name: status, dtype: int64

# %% [markdown]
# The status column has many missing values. However, the retired VTubers are marked, and thus, the missing value can be consider as active.
# The freq column indicates that the content release frequency of the VTuber.
# The subs (subscribe) and views (video views).

# %% [markdown]
# ### Data Cleaning
# Next I am going to clean the data and prepare for analysis.

# %%
# delete the meaningless column
vt_all_info_df.pop("Unnamed: 0")
vt_all_info_df.head()
# Out:
#                name   type_        group genre_list  gender language_list  \
# 0      Lize Helesta  VTuber    Nijisanji         []  Female  ['Japanese']
# 1            Naraka  VTuber    Nijisanji         []  Female  ['Japanese']
# 2      Takao Shinji  VTuber  Independent         []    Male  ['Japanese']
# 3  Shellin Burgundy  VTuber    Nijisanji         []    Male  ['Japanese']
# 4      Souya Ichika  VTuber      AniMare         []  Female  ['Japanese']
#
#       model_list       debut status               freq   subs   views
# 0  ['3D', 'L2D']  2019/03/23  + Add  Every 2.51 Day(s)   609k  104.6m
# 1        ['L2D']  2019/12/29  + Add  Every 1.91 Day(s)   285k   25.3m
# 2        ['L2D']       + Add  + Add  Every 1.83 Day(s)   151k   41.9m
# 3        ['L2D']  2019/09/21  + Add  Every 2.83 Day(s)   254k   29.9m
# 4  ['3D', 'L2D']  2018/06/09  + Add  Every 1.72 Day(s)  90.1k    9.4m

# %%
# convert the group into a binary category variable
vt_all_info_df["has_group"] = (vt_all_info_df.group != "Independent")
vt_all_info_df.head(10)
# Out:
#                   name      type_        group  genre_list  gender  \
# 0         Lize Helesta     VTuber    Nijisanji          []  Female
# 1               Naraka     VTuber    Nijisanji          []  Female
# 2         Takao Shinji     VTuber  Independent          []    Male
# 3     Shellin Burgundy     VTuber    Nijisanji          []    Male
# 4         Souya Ichika     VTuber      AniMare          []  Female
# 5  Shimamura Charlotte     VTuber   HoneyStrap          []  Female
# 6                  Cry  VStreamer  Independent     ['Art']  Female
# 7        Lumi Celestia     VTuber    MAHAPANCA          []  Female
# 8             Wolfychu  VStreamer  Independent  ['Gaming']  Female
# 9       Sakura Ritsuki     VTuber    Nijisanji          []  Female
#
#     language_list     model_list       debut  status               freq  \
# 0    ['Japanese']  ['3D', 'L2D']  2019/03/23   + Add  Every 2.51 Day(s)
# 1    ['Japanese']        ['L2D']  2019/12/29   + Add  Every 1.91 Day(s)
# ...

# %% [markdown]
# The release frequency column is string type now. It need to be parsed into float type. The structure of the string seems fixed but the column might has null values. I need to find the null values structure firstly.

# %%
# find the string structure of null values
vt_all_info_df[vt_all_info_df['freq'].apply(lambda x: True if x[:5] != "Every" else False)]
# Out:
#                                name   type_        group genre_list  gender  \
# 15  遠北千南 / Achikita Chinami 【にじさんじ】  VTuber  Independent         []  Female
#
#    language_list model_list  debut status freq subs views  has_group
# 15  ['Japanese']         []  + Add  + Add    —  77k  3.8m      False

# %%
# parse the freq -> float type
vt_all_info_df['freq_float'] = vt_all_info_df["freq"].apply(lambda x: x.split() if x[:5] == "Every" else [None, None])\
.apply(lambda x: float(x[1]) if x[1] else np.nan)

vt_all_info_df.head()
# Out:
#                name   type_        group genre_list  gender language_list  \
# 0      Lize Helesta  VTuber    Nijisanji         []  Female  ['Japanese']
# 1            Naraka  VTuber    Nijisanji         []  Female  ['Japanese']
# 2      Takao Shinji  VTuber  Independent         []    Male  ['Japanese']
# 3  Shellin Burgundy  VTuber    Nijisanji         []    Male  ['Japanese']
# 4      Souya Ichika  VTuber      AniMare         []  Female  ['Japanese']
#
#       model_list       debut status               freq   subs   views  \
# 0  ['3D', 'L2D']  2019/03/23  + Add  Every 2.51 Day(s)   609k  104.6m
# 1        ['L2D']  2019/12/29  + Add  Every 1.91 Day(s)   285k   25.3m
# 2        ['L2D']       + Add  + Add  Every 1.83 Day(s)   151k   41.9m
# 3        ['L2D']  2019/09/21  + Add  Every 2.83 Day(s)   254k   29.9m
# 4  ['3D', 'L2D']  2018/06/09  + Add  Every 1.72 Day(s)  90.1k    9.4m
#
#    has_group  freq_float
# 0       True        2.51
# 1       True        1.91
# ...

# %% [markdown]
# The number of subscribe and the number of view are strings, and they use k, m, and b to stand for thousand, million, and billion.

# %%
# subs and views convert to int
unit_trans = {'k': 1000, 'm': 1000000, 'b': 1000000000}

# vt_all_info_df["subs"].apply(lambda x: x[-1]).value_counts() # -> subs value have no missing value
# vt_all_info_df["views"].apply(lambda x: x[-1]).value_counts() # -> subs value have no missing value

vt_all_info_df["subs"] = vt_all_info_df["subs"].apply(lambda x: float(x[:-1]) * unit_trans[x[-1]])
vt_all_info_df["views"] = vt_all_info_df["views"].apply(lambda x: float(x[:-1]) * unit_trans[x[-1]])

vt_all_info_df.head()
# Out:
#                name   type_        group genre_list  gender language_list  \
# 0      Lize Helesta  VTuber    Nijisanji         []  Female  ['Japanese']
# 1            Naraka  VTuber    Nijisanji         []  Female  ['Japanese']
# 2      Takao Shinji  VTuber  Independent         []    Male  ['Japanese']
# 3  Shellin Burgundy  VTuber    Nijisanji         []    Male  ['Japanese']
# 4      Souya Ichika  VTuber      AniMare         []  Female  ['Japanese']
#
#       model_list       debut status               freq      subs        views  \
# 0  ['3D', 'L2D']  2019/03/23  + Add  Every 2.51 Day(s)  609000.0  104600000.0
# 1        ['L2D']  2019/12/29  + Add  Every 1.91 Day(s)  285000.0   25300000.0
# 2        ['L2D']       + Add  + Add  Every 1.83 Day(s)  151000.0   41900000.0
# 3        ['L2D']  2019/09/21  + Add  Every 2.83 Day(s)  254000.0   29900000.0
# 4  ['3D', 'L2D']  2018/06/09  + Add  Every 1.72 Day(s)   90100.0    9400000.0
#
#    has_group  freq_float
# 0       True        2.51
# ...

# %% [markdown]
# The debut date can convert to the exist days.

# %%
# convert the debut date into vtuber existence days

# dealing with mixed format of datetime
date1 = pd.to_datetime(vt_all_info_df.debut, errors="coerce", format="%Y/%m/%d")
date2 = pd.to_datetime(vt_all_info_df.debut, errors="coerce", format="%d/%m/%Y")
date3 = pd.to_datetime(vt_all_info_df.debut, errors="coerce", format="%m/%d/%Y")
date4 = pd.to_datetime(vt_all_info_df.debut, errors="coerce", format="%d %b %Y")
date5 = pd.to_datetime(vt_all_info_df.debut, errors="coerce", format="%d %B %Y")
date6 = pd.to_datetime(vt_all_info_df.debut, errors="coerce", format="%b %d %Y")

vt_all_info_df["debut_dt"] = date1
vt_all_info_df["debut_dt"].fillna(date2, inplace = True)
vt_all_info_df["debut_dt"].fillna(date3, inplace = True)
vt_all_info_df["debut_dt"].fillna(date4, inplace = True)
vt_all_info_df["debut_dt"].fillna(date5, inplace = True)
vt_all_info_df["debut_dt"].fillna(date6, inplace = True)

# %%
vt_all_info_df["exist_days"] = (pd.to_datetime("now") - vt_all_info_df["debut_dt"]).dt.days

# %%
vt_all_info_df.head()
# Out:
#                name   type_        group genre_list  gender language_list  \
# 0      Lize Helesta  VTuber    Nijisanji         []  Female  ['Japanese']
# 1            Naraka  VTuber    Nijisanji         []  Female  ['Japanese']
# 2      Takao Shinji  VTuber  Independent         []    Male  ['Japanese']
# 3  Shellin Burgundy  VTuber    Nijisanji         []    Male  ['Japanese']
# 4      Souya Ichika  VTuber      AniMare         []  Female  ['Japanese']
#
#       model_list       debut status               freq      subs        views  \
# 0  ['3D', 'L2D']  2019/03/23  + Add  Every 2.51 Day(s)  609000.0  104600000.0
# 1        ['L2D']  2019/12/29  + Add  Every 1.91 Day(s)  285000.0   25300000.0
# 2        ['L2D']       + Add  + Add  Every 1.83 Day(s)  151000.0   41900000.0
# 3        ['L2D']  2019/09/21  + Add  Every 2.83 Day(s)  254000.0   29900000.0
# 4  ['3D', 'L2D']  2018/06/09  + Add  Every 1.72 Day(s)   90100.0    9400000.0
#
#    has_group  freq_float   debut_dt  exist_days
# ...

# %% [markdown]
# Add a column named "is_active". The retired VTubers are False in the column, and other VTubers, including missing value, are True.

# %%
vt_all_info_df["is_active"] = vt_all_info_df.status != "Retired"
vt_all_info_df.head()
# Out:
#                name   type_        group genre_list  gender language_list  \
# 0      Lize Helesta  VTuber    Nijisanji         []  Female  ['Japanese']
# 1            Naraka  VTuber    Nijisanji         []  Female  ['Japanese']
# 2      Takao Shinji  VTuber  Independent         []    Male  ['Japanese']
# 3  Shellin Burgundy  VTuber    Nijisanji         []    Male  ['Japanese']
# 4      Souya Ichika  VTuber      AniMare         []  Female  ['Japanese']
#
#       model_list       debut status               freq      subs        views  \
# 0  ['3D', 'L2D']  2019/03/23  + Add  Every 2.51 Day(s)  609000.0  104600000.0
# 1        ['L2D']  2019/12/29  + Add  Every 1.91 Day(s)  285000.0   25300000.0
# 2        ['L2D']       + Add  + Add  Every 1.83 Day(s)  151000.0   41900000.0
# 3        ['L2D']  2019/09/21  + Add  Every 2.83 Day(s)  254000.0   29900000.0
# 4  ['3D', 'L2D']  2018/06/09  + Add  Every 1.72 Day(s)   90100.0    9400000.0
#
# ...

# %% [markdown]
# Turn all the non-binary (not male and not female) gender into "non-binary".

# %%
vt_all_info_df.gender.where(((vt_all_info_df.gender == "Male") | (vt_all_info_df.gender == "Female")), "Non-binary", inplace=True)
vt_all_info_df.head()
# Out:
#                name   type_        group genre_list  gender language_list  \
# 0      Lize Helesta  VTuber    Nijisanji         []  Female  ['Japanese']
# 1            Naraka  VTuber    Nijisanji         []  Female  ['Japanese']
# 2      Takao Shinji  VTuber  Independent         []    Male  ['Japanese']
# 3  Shellin Burgundy  VTuber    Nijisanji         []    Male  ['Japanese']
# 4      Souya Ichika  VTuber      AniMare         []  Female  ['Japanese']
#
#       model_list       debut status               freq      subs        views  \
# 0  ['3D', 'L2D']  2019/03/23  + Add  Every 2.51 Day(s)  609000.0  104600000.0
# 1        ['L2D']  2019/12/29  + Add  Every 1.91 Day(s)  285000.0   25300000.0
# 2        ['L2D']       + Add  + Add  Every 1.83 Day(s)  151000.0   41900000.0
# 3        ['L2D']  2019/09/21  + Add  Every 2.83 Day(s)  254000.0   29900000.0
# 4  ['3D', 'L2D']  2018/06/09  + Add  Every 1.72 Day(s)   90100.0    9400000.0
#
# ...

# %% [markdown]
# We finally have the well structured columns in our DataFrame. Now, we need to copy the necessary columns for the following sessions.

# %%
necessary_columns = ["name", "group", "has_group", \
                     "genre_list", "gender", "language_list", \
                     "model_list", "exist_days", "is_active", "freq_float", "subs", "views"]
vt_df = vt_all_info_df[necessary_columns].copy()
vt_df.sample(5)
# Out:
#               name        group  has_group              genre_list  \
# 351     LittleNii_  Independent      False                      []
# 367          しきぶTV  Independent      False                      []
# 18    WhisperMute   Independent      False  ['Chatting', 'Gaming']
# 495  Kenmochi Toya    Nijisanji       True                      []
# 272   Hinokuma Ran      AniMare       True                      []
#
#          gender language_list     model_list  exist_days  is_active  \
# 351      Female   ['English']             []         NaN       True
# 367      Female  ['Japanese']             []         NaN       True
# 18   Non-binary   ['English']         ['3D']      1252.0       True
# 495        Male  ['Japanese']  ['3D', 'L2D']      1396.0       True
# 272      Female  ['Japanese']        ['L2D']      1306.0       True
#
#      freq_float      subs        views
# 351        4.63  229800.0   15300000.0
# 367        1.01  144000.0  105900000.0
# ...

# %% [markdown]
# ### Exploratory Analysis and Visualisation

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import ast # the "list" in the vt_all_info_df is actually str, it need to be convert into list type by ast.literal_eval()
mpl.rcParams['figure.facecolor'] = 'white'
mpl.rcParams['figure.figsize'] = (10,7.5)
color_set = sns.color_palette('pastel')

# %% [markdown]
# #### General Information

# %%
vt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           500 non-null    object
#  1   group          500 non-null    object
#  2   has_group      500 non-null    bool
#  3   genre_list     500 non-null    object
#  4   gender         500 non-null    object
#  5   language_list  500 non-null    object
#  6   model_list     500 non-null    object
#  7   exist_days     355 non-null    float64
#  8   is_active      500 non-null    bool
#  9   freq_float     499 non-null    float64
#  10  subs           500 non-null    float64
#  11  views          500 non-null    float64
# dtypes: bool(2), float64(4), object(6)
# memory usage: 40.2+ KB

# %% [markdown]
# There are 6 object type columns. It is because they are categorical variables, and some columns are actually list type.
#
# There are 2 boolean columns. The column "has_group" indicates whether the VTuber is belong to a group (usually entertainment company). The column "is_active" indicates whether the VTuber has retired or not.
#
# At the beginning of the session, I would like to raise a question:
# > *is now a good time to be a VTuber?*
#
# Now let us dive into the numerical columns initially.

# %%
# describe the dataframe
vt_df.describe()
# Out:
#         exist_days  freq_float          subs         views
# count   355.000000  499.000000  5.000000e+02  5.000000e+02
# mean   1022.090141    5.608136  3.794032e+05  5.781228e+07
# std     438.202985   11.309039  6.509501e+05  3.441007e+08
# min      91.000000    0.270000  7.130000e+04  5.345000e+05
# 25%     707.000000    1.350000  1.120000e+05  7.200000e+06
# 50%    1057.000000    2.130000  1.940000e+05  1.755000e+07
# 75%    1316.000000    4.750000  3.882500e+05  5.435000e+07
# max    4474.000000  147.860000  1.100000e+07  7.600000e+09

# %% [markdown]
# It is not intuitive to see these statistics. Let's do some visualisation.

# %% [markdown]
# #### Exist Days

# %%
# exist days
fig, ax = plt.subplots(2,2, figsize = (28,9))

ax[0][0].boxplot(vt_df["exist_days"].dropna(), vert=False)
ax[0][0].set_yticklabels("")
ax[0][0].tick_params("y", direction = "in")
ax[0][0].set_title("Before removing outliers", fontsize = 14)

ax[1][0].hist(vt_df.exist_days, bins=50, edgecolor = "blue", color = color_set[0]);
ax[1][0].set_xlabel("exist time/ days", fontsize = 14)

ax[0][1].set_title("After removing outliers", fontsize = 14)
ax[0][1].boxplot(vt_df.exist_days[vt_df.exist_days < 2000], vert=False)
ax[0][1].set_yticklabels("")
ax[0][1].tick_params("y", direction = "in")

ax[1][1].hist(vt_df.exist_days[vt_df.exist_days < 2000], bins=50, edgecolor = "blue", color = color_set[0]);
ax[1][1].set_xlabel("exist time/ days", fontsize = 14);

# %%
vt_df.name[vt_df.exist_days > 2000]
# Out:
# 262         Ami Yamato
# 373           nux taku
# 465    Annoying Orange
# Name: name, dtype: object

# %% [markdown]
# From the left boxplot, we can know that there are three outliers in the exist_days column. They are an early attempt to make videos using avatars.
#
# After removing the outlier, we can see the mainstream VTubers' exist days. Return to our initial quesiton: *is now a good time to be a VTuber?*
#
# > Answer: If we look at the histogram from right to left, the shape of the histogram is similar to the famous Gartner hype cycle. From the 1600 to the 1300, which is from the middle of 2017 to the middle of the 2018, is the phase of peak of inflated expectations. From the 1300 to 1200, is the phase of trough of disillusionment. From the 1200 to 500, is the phase of slope of enlightenment. Then from 500 to now, it should be in the phase of plateau of productivity, but it seems in a shrinking stage.
# > In the above analysis, the VTuber field is in the phase of plateau of productivity. In the phase, the market will rise steadily.  Thus, roughly speaking, it is a good time to be a VTuber. However, we did not analyse it based on cost and income data of the VTubers.
#
# #### Release Frequency

# %%
# release frequency
fig, ax = plt.subplots(2,1, figsize = (14,9))

ax[0].boxplot(vt_df.freq_float.dropna(), vert=False)
ax[0].set_yticklabels("")
ax[0].tick_params("y", direction = "in")
# ax[0].set_title("Before removing outliers")

ax[1].hist(vt_df.freq_float.dropna(), bins=50, edgecolor = "blue", color = color_set[0]);
ax[1].set_xlabel("Release frequency", fontsize = 12);

# %% [markdown]
# Most of the VTubers release contents every 1 to 5 days. In other word, most VTubers are daily update to weekly update. (IQR: 1.35, 4.75) It is also a common update frequency for normal Youtubers.
# #### Subscription and Views

# %%
# subs and views
fig, ax = plt.subplots(2,1, figsize = (14,9))

ax[0].boxplot(vt_all_info_df.subs[vt_all_info_df.subs < 2000000], vert=False)
ax[0].set_yticklabels("")
ax[0].tick_params("y", direction = "in")
# ax[0].set_title("Before removing outliers")

ax[1].hist(vt_all_info_df.subs[vt_all_info_df.subs < 2000000], bins=50, edgecolor = "blue", color = color_set[0]);
ax[1].set_xlabel("number of subscription", fontsize = 12);

# %% [markdown]
# It is obvious that the large proportion of the VTuber have less then 250000 subscriptions. The minimum of the subscription is 71300. That is because the data is from the top 500 VTuber, and the 500th VTuber has 71300 subscriptions. The views data is similar.

# %%
fig, ax = plt.subplots(2,1, figsize = (14,9))

ax[0].boxplot(vt_all_info_df.views[vt_all_info_df.views < 2000000000], vert=False)
ax[0].set_yticklabels("")
ax[0].tick_params("y", direction = "in")
# ax[0].set_title("Before removing outliers")

ax[1].hist(vt_all_info_df.views[vt_all_info_df.views < 2000000000], bins=50, edgecolor = "blue", color = color_set[0]);
ax[1].set_xlabel("number of subscription", fontsize = 12);

# %% [markdown]
# The histograms of the three columns, freq_float, subs, and views, appear to have similar trends. Here we come to the second question:
# > *is the number of subscriptions has impact on the number of views? Is the release frequency has impact on the number of subscriptions?*
#
# To answer the questions, let's make scatter diagrams and do the linear regression between the variables.

# %%
# subs-views
plt.scatter(vt_df.subs,vt_df.views)
plt.xlabel("subs")
plt.ylabel("views");
vt_df.name[vt_df.subs > 5000000]
# Out:
# 465    Annoying Orange
# Name: name, dtype: object

# %% [markdown]
# There is an obvious outlier, which has high subscription number and extreme high views. The name of the outlier is Annoying Orange. After looking at his Youtube page, I found that he is a VTuber in board sense, but he creates video content for a wider audience than the general VTuber. Thus, I will remove his data in order to simplify our analysis.

# %%
# subs-views

from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# copy the subs and views data
x = np.array(vt_df.subs[vt_df.subs < 5000000]).reshape(-1,1)
y = np.array(vt_df.views[vt_df.subs < 5000000]).reshape(-1,1)

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=1)
print("Train Data X Shape %s, y Shape %s" % (x_train.shape, y_train.shape))
print("Test Data X Shape %s, y Shape %s" % (x_test.shape, y_test.shape))

model = LinearRegression(fit_intercept=True)
model.fit(x_train, y_train)

xfit = np.linspace(0, 5000000, 1000)
yfit = model.predict(xfit.reshape(1000, 1))

y_pred = model.predict(x_test)

plt.scatter(x, y)
plt.plot(xfit, yfit,color="red");

print("Model slope: ", model.coef_[0])
print("Model intercept:", model.intercept_)
print("R2 score: ", r2_score(y_test, y_pred))
# Out:
# Train Data X Shape (374, 1), y Shape (374, 1)
# Test Data X Shape (125, 1), y Shape (125, 1)
# Model slope:  [102.36583226]
# Model intercept: [5859925.39369611]
# R2 score:  0.5351962239209833

# %% [markdown]
# From the above linear regression result, it is apparent that the model is not very good. The R2 of the model is 0.535. There are two reasons for the bad result: 1. the linear model choice is wrong; 2. the error variance is high. Therefore, we cannot conclude that there is a linear relationship between the number of subscriptions and the number of views.

# %%
# freq - subs
plt.scatter(vt_df.freq_float,vt_df.subs)
plt.xlabel("release frequency")
plt.ylabel("subs");

# %% [markdown]
# As you can see from the scatter chart above, there is clearly no relationship between release frequency and number of subscriptions.

# %% [markdown]
# Let's turn to categorical variables now.
# #### Group

# %%
# group
Others_value = vt_df.group.value_counts()[vt_df.group.value_counts() < 5].sum()

group_bar_df = vt_df.group.value_counts()[vt_df.group.value_counts() >= 5].append\
(pd.Series({"Others": Others_value}))

plt.figure(figsize=(12,6), tight_layout = True)
plt.title("Group that the VTuber belongs to", fontsize = 15)
plt.grid(axis = 'y', linestyle = "--", zorder = 0)
plt.bar(group_bar_df.index, group_bar_df.values, color = color_set, zorder = 3)
plt.xticks(rotation=45,fontsize = 12)

for idx, val in enumerate(group_bar_df.values):
    plt.text(idx - 0.15, val + 3, val)
    
plt.yticks(np.linspace(0, 280, 5))
plt.text(6.5,220,"* Groups in others represent \n   they have less than 5 VTubers\
\n* Independent represents the number of \n   VTuber that not belongs to any group", fontsize = 14);

# %% [markdown]
# The largest percentage of VTuber are independent. It is reasonable that there are so many independent VTuber, because the cost of making a virtual model is not unreachable now.
#
# We can also see the Nijisanji and Hololive own many popular VTubers. Actually, the two grouop is the top 2 Japanese company in the field of the VTuber.
#
# #### Language

# %%
# language
language_bar_df = vt_df['language_list'].apply(ast.literal_eval).explode().value_counts()

plt.figure(figsize=(12,6), tight_layout = True)
plt.title("Language", fontsize = 15)
plt.grid(axis = 'y', linestyle = "--", zorder = 0)
plt.bar(language_bar_df.index, language_bar_df.values, color = color_set, zorder = 3)
plt.xticks(rotation= 45,fontsize = 12)
for idx, val in enumerate(language_bar_df.values):
    plt.text(idx - 0.15, val + 3, val)

# %% [markdown]
# In the bar chart, it appears that a high proportion of VTuber speaks Japanese, and the second highest language used by VTuber is English. The reason for it probably because the mainstream VTuber market is established by Japanese. Kizuna Ai is known as the first mainstream VTuber and she is a Japanese VTuber. Because of Kizuna Ai's success, the VTuber market was established and explosively expanded in the year 2017. It is also a possible reason why the top 2 VTuber groups are Japanese groups.
#
# Also, it is worth mentioning that the data in this study does not include Chinese market. Thus, the number of Chinese speaking VTuber is low in the chart.

# %% [markdown]
# #### Genre
# We have discussed so much about the data of the VTuber, but what contents are they actually create. To know the answer, let's look at the column of genre.

# %%
# genre
genre_bar_df = vt_df['genre_list'].apply(ast.literal_eval).explode().value_counts()

plt.figure(figsize=(12,6))
plt.title("Genre", fontsize = 15)
plt.grid(axis = 'y', linestyle = "--", zorder = 0)
plt.bar(genre_bar_df.index, genre_bar_df.values, color = color_set, zorder = 3);
plt.xticks(rotation= 45,fontsize = 12)

for idx, val in enumerate(genre_bar_df.values):
    plt.text(idx - 0.15, val + 2, val)

# %% [markdown]
# The most common genre of VTubers' content is gaming, the second most common is chatting, and the third most common is music.
#
# I also found an interesting coincidence here. The top 3 genre are exactly the top 3 most popular streaming categories (Gaming, Just Chatting, and Music) in Twitch. We can roughly infer that their audiences are probably the same.

# %%
model_hasgroup_bar_df = vt_df.model_list[vt_df.has_group == True].apply(ast.literal_eval).explode().value_counts()
model_nogroup_bar_df = vt_df.model_list[vt_df.has_group == False].apply(ast.literal_eval).explode().value_counts()

plt.figure(figsize=(16,9))
plt.title("Model Type", fontsize = 15)
plt.grid(axis = 'y', linestyle = "--", zorder = 0)

p1 = plt.bar(model_hasgroup_bar_df.index, model_hasgroup_bar_df.values, color = color_set[0], zorder = 3)
p2 = plt.bar(model_nogroup_bar_df.index, model_nogroup_bar_df.values,color = color_set[1], zorder = 3);

plt.xticks(fontsize = 12)


plt.legend((p1[0], p2[0]), ("Has group", "Independent"));

# %% [markdown]
# Most of the VTubers use Live2D and 3D models to make videos and do the live stream. Due to the high cost of creating 3D model and motion capture, there are less proportion of the VTubers use the 3D model than the Live2D model.
#
# The number of picture-types VTuber is small. It is because that one of the attractive features of the VTubers is the vivid facial expression by using facial capture and motion capture.
#
# #### Gender

# %%
# gender
gender_pie_df = vt_all_info_df["gender"].value_counts(normalize=True)


plt.pie(gender_pie_df, labels=gender_pie_df.index, labeldistance=1.1, colors=color_set, \
                        autopct = lambda p: format(p, '.1f') + '%' if p > 15 else None, \
                        explode = (0,0,0.2));
plt.title("VTuber gender distribution", fontsize = 20);

# %% [markdown]
# The female VTubers make up the majority of the field, and the percentage is 82.2%. Only 16.2% of the VTubers are male. The imbalance may be due to the high proportion of men in the audience.

# %% [markdown]
# #### Group and Subs
# The last question:
# > If I want to be a famous VTuber, should I join in a group?
#
# From the below scatter chart, we can notice that the VTubers that in a group seems have more subs and views. To answer the question, let's do a hypothesis test. The question is actually about two independent means. Therefore, we make the following hypotheses.
#
# $H_0$: Joining in a group has no effect on the number of subs -> $\mu_{has group}-\mu_{independent}=0$
# $H_a$: Joining in a group has effect on the number of subs -> $\mu_{has group}-\mu_{independent}>0$

# %%
# relation between subs and views
p1 = plt.scatter(vt_all_info_df.subs[(vt_all_info_df.subs < 5000000) & (vt_all_info_df.has_group)],\
            vt_all_info_df.views[(vt_all_info_df.subs < 5000000) & (vt_all_info_df.has_group)])
p2 = plt.scatter(vt_all_info_df.subs[(vt_all_info_df.subs < 5000000) & (~vt_all_info_df.has_group)],\
            vt_all_info_df.views[(vt_all_info_df.subs < 5000000) & (~vt_all_info_df.has_group)], marker='x')
plt.xlabel("Subs")
plt.ylabel("Views")

plt.legend((p1,p2), ("Has_group", "Independent"));

# %%
# If I want to be a famous VTuber, should I join in a group?
# H0: Joining in a group has no effect on the number of subs
# Ha: Joining in a group has effect on the number of subs
from scipy import stats

sample_in_group = vt_all_info_df.subs[vt_all_info_df.has_group == True]
sample_not_group = vt_all_info_df.subs[vt_all_info_df.has_group == False]

r = stats.ttest_ind(sample_in_group, sample_not_group, equal_var=False)


print("statistic:", r.__getattribute__("statistic"))
print("pvalue:", r.__getattribute__("pvalue"))
# Out:
# statistic: 2.8744237000231267
# pvalue: 0.004238605252967506

# %% [markdown]
# Since the p value is less than 0.05, we can reject the null hypothesis.
# There is statistical evidence to claim that joining in a group has effect on the number of subs. Thus, if you want to be a famous VTuber, it is better to join in a VTuber group.

# %% [markdown]
# ### Summary
# In this study, we have cleaned and analysed the data of the top 500 VTubers in the world.
# From the analysis we have learnt that:
# - The market of VTuber has come to the phase of plateau of productivity, and it may be a good time to be a VTuber.
# - Most VTubers release contents everyday to every five days.
# - It seems that the number of subscriptions has impact on the number of views, but the bad result of the linear regression model has shown that there is no linear relationship between the two metrics.
# - From the scatter plot, there is clearly no relationship between release frequency and number of subscriptions.
# - The largest percentage of VTuber are independent.
# - Japanese has the largest VTuber market.
# - More VTuber use Live2D than 3D as their model.
# - The proportion of female VTubers is much higher than that of male VTubers.
# - Joining in a group has effect on the number of subscriptions. Thus, if you want to be a VTuber, you'd better join in a group.
#
# ### Future Work
# The data in this study are only basic data, and the data does not include the Chinese market, which is a big VTuber market. To do the research of the VTuber market wider, the Chinese VTubers' data need to be collected. Besides, to make the study deeper, more variables like income, cost, the numbers of paying users, need to be collected and analysed.
